# %% [markdown]
# # **数据挖掘——Home Credit Default Risk**
#
# Authors：李林（3120220938）、杨洋（3220211141）、敬甲男（3220221052）、李翰杰（3120220936）
#
# github地址：https://github.com/leealim/kaggle-Home-Credit-Default-Risk
#
# ---
#
# ## 特征工程——特征选择
#
# 首先，处理合并表后的缺失值。
# 然后，通过多种方法筛选特征
#
# > 相关性排除
# > 特征重要性排除
#
# ---

# %%
# 引入本部分所需要的包，并定义需要的值和函数

import pandas as pd
import numpy as np
import os

source_dir="..\\data\\table_merge"
result_dir="..\\data\\choosing"

app_tr_path = source_dir+"\\application_train.csv"
app_te_path = source_dir+"\\application_test.csv"
bur_path = source_dir+"\\bureau.csv"
bur_bal_path = source_dir+"\\bureau_balance.csv"
pos_path = source_dir+"\\POS_CASH_balance.csv"
cre_path = source_dir+"\\credit_card_balance.csv"
pre_path = source_dir+"\\previous_application.csv"
ins_path = source_dir+"\\installments_payments.csv"
hom_path = "..\\data\\home-credit-default-risk\\HomeCredit_columns_description.csv"  # 列描述表
hom = pd.read_csv(hom_path)

if not os.path.exists(result_dir):
    os.makedirs(result_dir)

# %%
app_tr = pd.read_csv(app_tr_path)
app_te = pd.read_csv(app_te_path)

# %%
app_tr.isnull().any(axis=0)
# Out:
# SK_ID_CURR                    False
# NAME_CONTRACT_TYPE            False
# FLAG_OWN_CAR                  False
# FLAG_OWN_REALTY               False
# CNT_CHILDREN                  False
#                               ...
# WALLSMATERIAL_MODE_Wooden     False
# EMERGENCYSTATE_MODE_MyNull    False
# EMERGENCYSTATE_MODE_No        False
# EMERGENCYSTATE_MODE_Yes       False
# TARGET                        False
# Length: 1103, dtype: bool

# %%
app_te.isnull().any(axis=1)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 48739    True
# 48740    True
# 48741    True
# 48742    True
# 48743    True
# Length: 48744, dtype: bool

# %% [markdown]
# 发现存在大量缺失值，这里简单用其平均值替换

# %%
for c in app_tr.columns:
    mean_num=app_tr[c].mean()
    if app_tr[c].isnull().sum()>0:
        app_tr[c].fillna(mean_num,inplace=True)
    if str(c)!="TARGET" and app_te[c].isnull().sum()>0:
        app_te[c].fillna(mean_num,inplace=True)

# %%
app_tr.isnull().any(axis=0).sum()
# Out:
# 0

# %%
# 根据相关性排除部分列

threshold = 0.9

corr_matrix = app_tr.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool_))
to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

app_tr = app_tr.drop(columns = to_drop)
app_te = app_te.drop(columns = to_drop)
app_tr
# Out:
#         SK_ID_CURR  NAME_CONTRACT_TYPE  FLAG_OWN_CAR  FLAG_OWN_REALTY
# 0           100002                   0             0                1  \
# 1           100003                   0             0                0
# 2           100004                   1             1                1
# 3           100006                   0             0                1
# 4           100007                   0             0                1
# ...            ...                 ...           ...              ...
# 290616      456249                   0             0                1
# 290617      456251                   0             0                0
# 290618      456252                   0             0                1
# 290619      456254                   0             0                1
# 290620      456255                   0             0                0
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY
# 0                  0          202500.0    406597.5      24700.5  \
# 1                  0          270000.0   1293502.5      35698.5
# 2                  0           67500.0    135000.0       6750.0
# 3                  0          135000.0    312682.5      29686.5
# 4                  0          121500.0    513000.0      21865.5
# ...              ...               ...         ...          ...
# 290616             0          112500.0    225000.0      22050.0
# 290617             0          157500.0    254700.0      27558.0
# 290618             0           72000.0    269550.0      12001.5
# 290619             0          171000.0    370107.0      20205.0
# 290620             0          157500.0    675000.0      49117.5
#
#         REGION_POPULATION_RELATIVE  DAYS_BIRTH  ...
# 0                         0.018801       -9461  ...  \
# 1                         0.003541      -16765  ...
# 2                         0.010032      -19046  ...
# 3                         0.008019      -19005  ...
# 4                         0.028663      -19932  ...
# ...                            ...         ...  ...
# 290616                    0.022800      -24384  ...
# 290617                    0.032561       -9327  ...
# 290618                    0.025164      -20775  ...
# 290619                    0.005313      -11961  ...
# 290620                    0.046220      -16856  ...
#
#         HOUSETYPE_MODE_terraced house  WALLSMATERIAL_MODE_Block
# 0                               False                     False  \
# 1                               False                      True
# 2                               False                     False
# 3                               False                     False
# 4                               False                     False
# ...                               ...                       ...
# 290616                          False                     False
# 290617                          False                     False
# 290618                          False                     False
# 290619                          False                     False
# 290620                          False                     False
#
#         WALLSMATERIAL_MODE_Mixed  WALLSMATERIAL_MODE_Monolithic
# 0                          False                          False  \
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                          False
# ...                          ...                            ...
# 290616                     False                          False
# 290617                     False                          False
# 290618                     False                          False
# 290619                     False                          False
# 290620                     False                          False
#
#         WALLSMATERIAL_MODE_Others  WALLSMATERIAL_MODE_Panel
# 0                           False                     False  \
# 1                           False                     False
# 2                           False                     False
# 3                           False                     False
# 4                           False                     False
# ...                           ...                       ...
# 290616                      False                      True
# 290617                      False                     False
# 290618                      False                     False
# 290619                      False                     False
# 290620                      False                      True
#
#         WALLSMATERIAL_MODE_Stone, brick  WALLSMATERIAL_MODE_Wooden
# 0                                  True                      False  \
# 1                                 False                      False
# 2                                 False                      False
# 3                                 False                      False
# 4                                 False                      False
# ...                                 ...                        ...
# 290616                            False                      False
# 290617                             True                      False
# 290618                             True                      False
# 290619                             True                      False
# 290620                            False                      False
#
#         EMERGENCYSTATE_MODE_Yes  TARGET
# 0                         False       1
# 1                         False       0
# 2                         False       0
# 3                         False       0
# 4                         False       0
# ...                         ...     ...
# 290616                    False       0
# 290617                    False       0
# 290618                    False       0
# 290619                    False       1
# 290620                    False       0
#
# [290621 rows x 650 columns]

# %%
# 根据特征重要性选择列

from sklearn.model_selection import train_test_split
import xgboost
feature_importances=np.zeros(app_tr.iloc[:,1:-1].shape[1])
# import re
# train = train.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
model = xgboost.XGBClassifier()
for i in range(2):
    x_train, x_test, y_train, y_test = train_test_split(
        app_tr.iloc[:,1:-1], app_tr.iloc[:,-1], test_size=0.25, random_state=i)
    model.fit(x_train, y_train)
    feature_importances += model.feature_importances_

feature_importances = feature_importances / 2
feature_importances = pd.DataFrame({'feature': list(
    app_tr.iloc[:,1:-1].columns), 'importance': feature_importances}).sort_values('importance', ascending=False)

# %%
pd.set_option("display.max_rows", 200)
pd.set_option('max_colwidth',40)
del_fea=feature_importances.loc[feature_importances["importance"]==0]
del_fea
# Out:
#                                      feature  importance
# 55                 AMT_REQ_CREDIT_BUREAU_DAY         0.0
# 54                AMT_REQ_CREDIT_BUREAU_HOUR         0.0
# 580  ORGANIZATION_TYPE_Business Entity Ty...         0.0
# 51                          FLAG_DOCUMENT_19         0.0
# 53                          FLAG_DOCUMENT_21         0.0
# 50                          FLAG_DOCUMENT_18         0.0
# 578                   ORGANIZATION_TYPE_Bank         0.0
# 577            ORGANIZATION_TYPE_Agriculture         0.0
# 576            ORGANIZATION_TYPE_Advertising         0.0
# 76     previous_RATE_INTEREST_PRIVILEGED_sum         0.0
# 52                          FLAG_DOCUMENT_20         0.0
# 629      ORGANIZATION_TYPE_Transport: type 2         0.0
# 13                                FLAG_MOBIL         0.0
# 115  previous_NAME_GOODS_CATEGORY_Animals...         0.0
# 121  previous_NAME_CASH_LOAN_PURPOSE_Mone...         0.0
# 120  previous_NAME_CASH_LOAN_PURPOSE_Refu...         0.0
# 119  previous_NAME_CASH_LOAN_PURPOSE_Refu...         0.0
# 118  previous_NAME_GOODS_CATEGORY_House C...         0.0
# 117  previous_NAME_GOODS_CATEGORY_House C...         0.0
# 555                 OCCUPATION_TYPE_HR staff         0.0
# 116  previous_NAME_GOODS_CATEGORY_Animals...         0.0
# 557                 OCCUPATION_TYPE_IT staff         0.0
# 114    previous_RATE_INTEREST_PRIVILEGED_min         0.0
# 567           OCCUPATION_TYPE_Security staff         0.0
# 113       previous_RATE_INTEREST_PRIMARY_min         0.0
# 87       previous_NFLAG_LAST_APPL_IN_DAY_max         0.0
# 563    OCCUPATION_TYPE_Private service staff         0.0
# 49                          FLAG_DOCUMENT_17         0.0
# 646                WALLSMATERIAL_MODE_Wooden         0.0
# 564            OCCUPATION_TYPE_Realty agents         0.0
# 85       previous_NFLAG_LAST_APPL_IN_DAY_min         0.0
# 79    previous_NFLAG_INSURED_ON_APPROVAL_max         0.0
# 15                          FLAG_CONT_MOBILE         0.0
# 591      ORGANIZATION_TYPE_Industry: type 10         0.0
# 48                          FLAG_DOCUMENT_16         0.0
# 37                           FLAG_DOCUMENT_5         0.0
# 42                          FLAG_DOCUMENT_10         0.0
# 640                 WALLSMATERIAL_MODE_Block         0.0
# 41                           FLAG_DOCUMENT_9         0.0
# 613               ORGANIZATION_TYPE_Religion         0.0
# 40                           FLAG_DOCUMENT_8         0.0
# 39                           FLAG_DOCUMENT_7         0.0
# 616               ORGANIZATION_TYPE_Security         0.0
# 617    ORGANIZATION_TYPE_Security Ministries         0.0
# 619               ORGANIZATION_TYPE_Services         0.0
# 43                          FLAG_DOCUMENT_11         0.0
# 632             ORGANIZATION_TYPE_University         0.0
# 621          ORGANIZATION_TYPE_Trade: type 1         0.0
# 34                           FLAG_DOCUMENT_2         0.0
# 622          ORGANIZATION_TYPE_Trade: type 2         0.0
# 623          ORGANIZATION_TYPE_Trade: type 3         0.0
# 624          ORGANIZATION_TYPE_Trade: type 4         0.0
# 625          ORGANIZATION_TYPE_Trade: type 5         0.0
# 36                           FLAG_DOCUMENT_4         0.0
# 608                 ORGANIZATION_TYPE_Mobile         0.0
# 606               ORGANIZATION_TYPE_Medicine         0.0
# 47                          FLAG_DOCUMENT_15         0.0
# 594      ORGANIZATION_TYPE_Industry: type 13         0.0
# 585            ORGANIZATION_TYPE_Electricity         0.0
# 586              ORGANIZATION_TYPE_Emergency         0.0
# 588                  ORGANIZATION_TYPE_Hotel         0.0
# 589                ORGANIZATION_TYPE_Housing         0.0
# 590       ORGANIZATION_TYPE_Industry: type 1         0.0
# 628      ORGANIZATION_TYPE_Transport: type 1         0.0
# 592      ORGANIZATION_TYPE_Industry: type 11         0.0
# 642            WALLSMATERIAL_MODE_Monolithic         0.0
# 595       ORGANIZATION_TYPE_Industry: type 2         0.0
# 122  previous_NAME_CASH_LOAN_PURPOSE_Mone...         0.0
# 46                          FLAG_DOCUMENT_14         0.0
# 597       ORGANIZATION_TYPE_Industry: type 4         0.0
# 599       ORGANIZATION_TYPE_Industry: type 6         0.0
# 600       ORGANIZATION_TYPE_Industry: type 7         0.0
# 601       ORGANIZATION_TYPE_Industry: type 8         0.0
# 45                          FLAG_DOCUMENT_13         0.0
# 603              ORGANIZATION_TYPE_Insurance         0.0
# 44                          FLAG_DOCUMENT_12         0.0
# 605         ORGANIZATION_TYPE_Legal Services         0.0
# 409  client_credit_AMT_DRAWINGS_OTHER_CUR...         0.0
# 123  previous_NAME_CASH_LOAN_PURPOSE_Hobb...         0.0
# 201  previous_FLAG_LAST_APPL_PER_CONTRACT...         0.0
# 222  previous_NAME_CASH_LOAN_PURPOSE_Buyi...         0.0
# 217  previous_NAME_CASH_LOAN_PURPOSE_Ever...         0.0
# 216  previous_NAME_CASH_LOAN_PURPOSE_Educ...         0.0
# 212  previous_NAME_SELLER_INDUSTRY_Indust...         0.0
# 210  previous_NAME_CASH_LOAN_PURPOSE_Repa...         0.0
# 208  previous_PRODUCT_COMBINATION_POS oth...         0.0
# 206  previous_PRODUCT_COMBINATION_POS oth...         0.0
# 205  previous_NAME_GOODS_CATEGORY_Medical...         0.0
# 468  client_credit_CNT_DRAWINGS_ATM_CURRE...         0.0
# 469  client_credit_AMT_DRAWINGS_ATM_CURRE...         0.0
# 198  previous_NAME_GOODS_CATEGORY_Auto Ac...         0.0
# 124  previous_NAME_CASH_LOAN_PURPOSE_Hobb...         0.0
# 196  previous_NAME_CASH_LOAN_PURPOSE_Urge...         0.0
# 194   previous_NAME_GOODS_CATEGORY_Other_sum         0.0
# 193  previous_NAME_GOODS_CATEGORY_Other_mean         0.0
# 192  previous_NAME_CASH_LOAN_PURPOSE_Buyi...         0.0
# 191  previous_NAME_CASH_LOAN_PURPOSE_Buyi...         0.0
# 190  previous_NAME_GOODS_CATEGORY_Jewelry...         0.0
# 188  previous_NAME_GOODS_CATEGORY_Office ...         0.0
# 187  previous_NAME_GOODS_CATEGORY_Office ...         0.0
# 186  previous_NAME_CASH_LOAN_PURPOSE_Medi...         0.0
# 184      previous_CODE_REJECT_REASON_XNA_sum         0.0
# 224  previous_NAME_CASH_LOAN_PURPOSE_Paym...         0.0
# 225  previous_NAME_GOODS_CATEGORY_Homewar...         0.0
# 226  previous_NAME_CASH_LOAN_PURPOSE_Paym...         0.0
# 232  previous_NAME_CONTRACT_STATUS_Unused...         0.0
# 407             client_credit_SK_DPD_min_sum         0.0
# 406            client_credit_SK_DPD_min_mean         0.0
# 380          client_cash_SK_DPD_DEF_min_mean         0.0
# 379               client_cash_SK_DPD_min_min         0.0
# 378           client_cash_SK_DPD_DEF_min_min         0.0
# 419  client_credit_AMT_DRAWINGS_ATM_CURRE...         0.0
# 342  previous_PRODUCT_COMBINATION_POS oth...         0.0
# 339  previous_NAME_SELLER_INDUSTRY_Auto t...         0.0
# 423  client_credit_CNT_DRAWINGS_OTHER_CUR...         0.0
# 326  previous_PRODUCT_COMBINATION_POS ind...         0.0
# 304  previous_PRODUCT_COMBINATION_POS mob...         0.0
# 294  previous_NAME_GOODS_CATEGORY_Audio/V...         0.0
# 287  previous_NAME_GOODS_CATEGORY_Constru...         0.0
# 264  previous_NAME_GOODS_CATEGORY_Gardeni...         0.0
# 259  previous_NAME_TYPE_SUITE_Spouse, par...         0.0
# 252  previous_PRODUCT_COMBINATION_POS ind...         0.0
# 247  previous_PRODUCT_COMBINATION_Cash St...         0.0
# 242     previous_NAME_TYPE_SUITE_Other_A_sum         0.0
# 240  previous_NAME_SELLER_INDUSTRY_Clothi...         0.0
# 238        previous_NAME_CLIENT_TYPE_XNA_sum         0.0
# 237       previous_NAME_CLIENT_TYPE_XNA_mean         0.0
# 183  previous_NAME_GOODS_CATEGORY_Tourism...         0.0
# 486  client_installments_NUM_INSTALMENT_N...         0.0
# 182  previous_NAME_SELLER_INDUSTRY_Touris...         0.0
# 144  previous_NAME_GOODS_CATEGORY_Direct ...         0.0
# 141  previous_NAME_SELLER_INDUSTRY_MLM pa...         0.0
# 521                 NAME_TYPE_SUITE_Children         0.0
# 523          NAME_TYPE_SUITE_Group of people         0.0
# 524                  NAME_TYPE_SUITE_Other_A         0.0
# 138  previous_NAME_GOODS_CATEGORY_Fitness...         0.0
# 137  previous_NAME_GOODS_CATEGORY_Fitness...         0.0
# 408  client_credit_CNT_DRAWINGS_OTHER_CUR...         0.0
# 136  previous_NAME_CASH_LOAN_PURPOSE_Busi...         0.0
# 531                 NAME_INCOME_TYPE_Student         0.0
# 532              NAME_INCOME_TYPE_Unemployed         0.0
# 135  previous_NAME_CASH_LOAN_PURPOSE_Busi...         0.0
# 134  previous_NAME_GOODS_CATEGORY_Insuran...         0.0
# 133  previous_NAME_GOODS_CATEGORY_Insuran...         0.0
# 132  previous_NAME_CASH_LOAN_PURPOSE_Buyi...         0.0
# 131  previous_NAME_CASH_LOAN_PURPOSE_Buyi...         0.0
# 130  previous_NAME_CASH_LOAN_PURPOSE_Gasi...         0.0
# 128  previous_NAME_GOODS_CATEGORY_Additio...         0.0
# 127  previous_NAME_GOODS_CATEGORY_Additio...         0.0
# 126  previous_NAME_GOODS_CATEGORY_Educati...         0.0
# 544        NAME_HOUSING_TYPE_Co-op apartment         0.0
# 125  previous_NAME_GOODS_CATEGORY_Educati...         0.0
# 142  previous_NAME_SELLER_INDUSTRY_MLM pa...         0.0
# 146  previous_NAME_CASH_LOAN_PURPOSE_Purc...         0.0
# 180  previous_NAME_GOODS_CATEGORY_Tourism...         0.0
# 150  previous_NAME_CASH_LOAN_PURPOSE_Furn...         0.0
# 489  client_installments_NUM_INSTALMENT_V...         0.0
# 179  previous_NAME_SELLER_INDUSTRY_Touris...         0.0
# 178  previous_NAME_CASH_LOAN_PURPOSE_Buyi...         0.0
# 176  previous_NAME_PAYMENT_TYPE_Non-cash ...         0.0
# 174  previous_NAME_PAYMENT_TYPE_Cashless ...         0.0
# 172  previous_NAME_SELLER_INDUSTRY_Jewelr...         0.0
# 170  previous_NAME_TYPE_SUITE_Group of pe...         0.0
# 168  previous_NAME_CASH_LOAN_PURPOSE_Car ...         0.0
# 166     previous_CHANNEL_TYPE_Car dealer_sum         0.0
# 165    previous_CHANNEL_TYPE_Car dealer_mean         0.0
# 164  previous_NAME_GOODS_CATEGORY_Sport a...         0.0
# 162  previous_NAME_CASH_LOAN_PURPOSE_Buyi...         0.0
# 161  previous_NAME_CASH_LOAN_PURPOSE_Buyi...         0.0
# 160  previous_NAME_GOODS_CATEGORY_Medicin...         0.0
# 158  previous_NAME_CASH_LOAN_PURPOSE_Buil...         0.0
# 156      previous_NAME_CONTRACT_TYPE_XNA_sum         0.0
# 155     previous_NAME_CONTRACT_TYPE_XNA_mean         0.0
# 154   previous_CODE_REJECT_REASON_SYSTEM_sum         0.0
# 153  previous_CODE_REJECT_REASON_SYSTEM_mean         0.0
# 152  previous_NAME_GOODS_CATEGORY_Weapon_sum         0.0
# 151  previous_NAME_GOODS_CATEGORY_Weapon_...         0.0
# 528             NAME_INCOME_TYPE_Businessman         0.0

# %%
app_tr = app_tr.drop(columns = del_fea["feature"])
app_te = app_te.drop(columns = del_fea["feature"])

# %%
print(app_tr.shape)
print(app_te.shape)
# Out:
# (290621, 472)
# (48744, 471)

# %%
# 使用均值归一化

for c in app_tr.columns:
    mean_num=app_tr[c].mean()
    std_num=app_tr[c].std()
    if str(c)=="TARGET" or str(c)=="SK_ID_CURR":
        continue
    app_tr[c]=(app_tr[c]-mean_num)/ std_num
    app_te[c]=(app_te[c]-mean_num)/ std_num
app_tr
# Out:
#         SK_ID_CURR  NAME_CONTRACT_TYPE  FLAG_OWN_CAR  FLAG_OWN_REALTY
# 0           100002           -0.316760     -0.712885         0.642653  \
# 1           100003           -0.316760     -0.712885        -1.556045
# 2           100004            3.156958      1.402745         0.642653
# 3           100006           -0.316760     -0.712885         0.642653
# 4           100007           -0.316760     -0.712885         0.642653
# ...            ...                 ...           ...              ...
# 290616      456249           -0.316760     -0.712885         0.642653
# 290617      456251           -0.316760     -0.712885        -1.556045
# 290618      456252           -0.316760     -0.712885         0.642653
# 290619      456254           -0.316760     -0.712885         0.642653
# 290620      456255           -0.316760     -0.712885        -1.556045
#
#         CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY
# 0          -0.579391          0.417004   -0.472921    -0.165293  \
# 1          -0.579391          1.184640    1.796178     0.614127
# 2          -0.579391         -1.118267   -1.167788    -1.437432
# 3          -0.579391         -0.350631   -0.713197     0.188061
# 4          -0.579391         -0.504158   -0.200696    -0.366208
# ...              ...               ...         ...          ...
# 290616     -0.579391         -0.606510   -0.937528    -0.353132
# 290617     -0.579391         -0.094753   -0.861542     0.037216
# 290618     -0.579391         -1.067091   -0.823549    -1.065262
# 290619     -0.579391          0.058774   -0.566280    -0.483886
# 290620     -0.579391         -0.094753    0.213773     1.565122
#
#         REGION_POPULATION_RELATIVE  DAYS_BIRTH  ...
# 0                        -0.138066    1.521449  ...  \
# 1                        -1.257267   -0.150922  ...
# 2                        -0.781203   -0.673195  ...
# 3                        -0.928841   -0.663807  ...
# 4                         0.585234   -0.876059  ...
# ...                            ...         ...  ...
# 290616                    0.155229   -1.895418  ...
# 290617                    0.871122    1.552131  ...
# 290618                    0.328610   -1.069078  ...
# 290619                   -1.127305    0.949033  ...
# 290620                    1.872903   -0.171758  ...
#
#         FONDKAPREMONT_MODE_reg oper account
# 0                                  1.792412  \
# 1                                  1.792412
# 2                                 -0.557905
# 3                                 -0.557905
# 4                                 -0.557905
# ...                                     ...
# 290616                             1.792412
# 290617                             1.792412
# 290618                             1.792412
# 290619                            -0.557905
# 290620                            -0.557905
#
#         FONDKAPREMONT_MODE_reg oper spec account
# 0                                     -0.201486   \
# 1                                     -0.201486
# 2                                     -0.201486
# 3                                     -0.201486
# 4                                     -0.201486
# ...                                         ...
# 290616                                -0.201486
# 290617                                -0.201486
# 290618                                -0.201486
# 290619                                -0.201486
# 290620                                -0.201486
#
#         HOUSETYPE_MODE_specific housing  HOUSETYPE_MODE_terraced house
# 0                             -0.070022                      -0.062699  \
# 1                             -0.070022                      -0.062699
# 2                             -0.070022                      -0.062699
# 3                             -0.070022                      -0.062699
# 4                             -0.070022                      -0.062699
# ...                                 ...                            ...
# 290616                        -0.070022                      -0.062699
# 290617                        -0.070022                      -0.062699
# 290618                        -0.070022                      -0.062699
# 290619                        -0.070022                      -0.062699
# 290620                        -0.070022                      -0.062699
#
#         WALLSMATERIAL_MODE_Mixed  WALLSMATERIAL_MODE_Others
# 0                      -0.086574                  -0.072318  \
# 1                      -0.086574                  -0.072318
# 2                      -0.086574                  -0.072318
# 3                      -0.086574                  -0.072318
# 4                      -0.086574                  -0.072318
# ...                          ...                        ...
# 290616                 -0.086574                  -0.072318
# 290617                 -0.086574                  -0.072318
# 290618                 -0.086574                  -0.072318
# 290619                 -0.086574                  -0.072318
# 290620                 -0.086574                  -0.072318
#
#         WALLSMATERIAL_MODE_Panel  WALLSMATERIAL_MODE_Stone, brick
# 0                      -0.518730                         1.944590  \
# 1                      -0.518730                        -0.514245
# 2                      -0.518730                        -0.514245
# 3                      -0.518730                        -0.514245
# 4                      -0.518730                        -0.514245
# ...                          ...                              ...
# 290616                  1.927778                        -0.514245
# 290617                 -0.518730                         1.944590
# 290618                 -0.518730                         1.944590
# 290619                 -0.518730                         1.944590
# 290620                  1.927778                        -0.514245
#
#         EMERGENCYSTATE_MODE_Yes  TARGET
# 0                     -0.087935       1
# 1                     -0.087935       0
# 2                     -0.087935       0
# 3                     -0.087935       0
# 4                     -0.087935       0
# ...                         ...     ...
# 290616                -0.087935       0
# 290617                -0.087935       0
# 290618                -0.087935       0
# 290619                -0.087935       1
# 290620                -0.087935       0
#
# [290621 rows x 472 columns]

# %%
# 输出结果

app_tr.to_csv(result_dir+"\\application_train.csv",index=False)
app_te.to_csv(result_dir+"\\application_test.csv",index=False)
